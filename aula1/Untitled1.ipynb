# %%
import pandas as pd

# %%
df = pd.read_csv("../data/test.csv")

# %%
! ls ../data
# Out:
# aluguel.csv  gender_submission.csv  ml-100k  test.csv  train.csv

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df['Sex'].value_counts()
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
df['Age'].sort_values(ascending=False)
df.loc[ 90:100 , :]
# Out:
#      PassengerId  Pclass                                               Name  \
# 90           982       3  Dyker, Mrs. Adolf Fredrik (Anna Elisabeth Judi...
# 91           983       3                                 Pedersen, Mr. Olaf
# 92           984       1               Davidson, Mrs. Thornton (Orian Hays)
# 93           985       3                                  Guest, Mr. Robert
# 94           986       1                                Birnbaum, Mr. Jakob
# 95           987       3                         Tenglin, Mr. Gunnar Isidor
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 97           989       3                          Makinen, Mr. Kalle Edvard
# 98           990       3                       Braf, Miss. Elin Ester Maria
# 99           991       3                       Nancarrow, Mr. William Henry
# 100          992       1  Stengel, Mrs. Charles Emil Henry (Annie May Mo...
#
#         Sex   Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# 90   female  22.0      1      0             347072  13.9000   NaN        S
# 91     male   NaN      0      0             345498   7.7750   NaN        S
# 92   female  27.0      1      2         F.C. 12750  52.0000   B71        S
# 93     male   NaN      0      0             376563   8.0500   NaN        S
# 94     male  25.0      0      0              13905  26.0000   NaN        C
# 95     male  25.0      0      0             350033   7.7958   NaN        S
# 96   female  76.0      1      0              19877  78.8500   C46        S
# 97     male  29.0      0      0  STON/O 2. 3101268   7.9250   NaN        S
# 98   female  20.0      0      0             347471   7.8542   NaN        S
# 99     male  33.0      0      0         A./5. 3338   8.0500   NaN        S
# 100  female  43.0      1      0              11778  55.4417  C116        C

# %%
df = df.set_index('PassengerId')
df.head()
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0   330911   7.8292   NaN        Q
# 893          47.0      1      0   363272   7.0000   NaN        S
# 894          62.0      0      0   240276   9.6875   NaN        Q
# 895          27.0      0      0   315154   8.6625   NaN        S
# 896          22.0      1      1  3101298  12.2875   NaN        S

# %%
df = df.reset_index()
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df['PassengerId'] = df['PassengerId'].astype(str)
df.head()
# Out:
#   PassengerId  Pclass                                          Name     Sex  \
# 0         892       3                              Kelly, Mr. James    male
# 1         893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2         894       2                     Myles, Mr. Thomas Francis    male
# 3         895       3                              Wirz, Mr. Albert    male
# 4         896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.dtypes
# Out:
# PassengerId     object
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df = df.set_index('PassengerId')

# %%
df.loc[ '892':'894' , :].head()
# Out:
#              Pclass                              Name     Sex   Age  SibSp  \
# PassengerId
# 892               3                  Kelly, Mr. James    male  34.5      0
# 893               3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 894               2         Myles, Mr. Thomas Francis    male  62.0      0
#
#              Parch  Ticket    Fare Cabin Embarked
# PassengerId
# 892              0  330911  7.8292   NaN        Q
# 893              0  363272  7.0000   NaN        S
# 894              0  240276  9.6875   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## SELECAO

# %%
df.head()
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0   330911   7.8292   NaN        Q
# 893          47.0      1      0   363272   7.0000   NaN        S
# 894          62.0      0      0   240276   9.6875   NaN        Q
# 895          27.0      0      0   315154   8.6625   NaN        S
# 896          22.0      1      1  3101298  12.2875   NaN        S

# %%
mask = df['Age'] > 40

# %%
df[mask].head()
# Out:
#              Pclass                                               Name  \
# PassengerId
# 893               3                   Wilkes, Mrs. James (Ellen Needs)
# 894               2                          Myles, Mr. Thomas Francis
# 903               1                         Jones, Mr. Charles Cresson
# 905               2                               Howard, Mr. Benjamin
# 906               1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
#
#                 Sex   Age  SibSp  Parch       Ticket     Fare Cabin Embarked
# PassengerId
# 893          female  47.0      1      0       363272   7.0000   NaN        S
# 894            male  62.0      0      0       240276   9.6875   NaN        Q
# 903            male  46.0      0      0          694  26.0000   NaN        S
# 905            male  63.0      1      0        24065  26.0000   NaN        S
# 906          female  47.0      1      0  W.E.P. 5734  61.1750   E31        S

# %%
mask1 = df['Age'] > 50
mask2 = df['Sex'] == 'male'

# %%
mask3 = mask1 | mask2

# %%
df[mask3]
# Out:
#              Pclass                             Name   Sex   Age  SibSp  \
# PassengerId
# 894               2        Myles, Mr. Thomas Francis  male  62.0      0
# 905               2             Howard, Mr. Benjamin  male  63.0      1
# 912               1           Rothschild, Mr. Martin  male  55.0      1
# 973               1               Straus, Mr. Isidor  male  67.0      1
# 1023              1        Gracie, Col. Archibald IV  male  53.0      0
# 1034              1       Ryerson, Mr. Arthur Larned  male  61.0      1
# 1044              3               Storey, Mr. Thomas  male  60.5      0
# 1069              1  Stengel, Mr. Charles Emil Henry  male  54.0      1
# 1085              2                Lingane, Mr. John  male  61.0      0
# 1109              1         Wick, Mr. George Dennick  male  57.0      1
# 1128              1         Warren, Mr. Frank Manley  male  64.0      1
# 1185              1            Dodge, Dr. Washington  male  53.0      1
# 1200              1       Hays, Mr. Charles Melville  male  55.0      1
# 1208              1    Spencer, Mr. William Augustus  male  57.0      1
# 1270              1      Hipkins, Mr. William Edward  male  55.0      0
# 1279              2                  Ashby, Mr. John  male  57.0      0
#
#              Parch    Ticket      Fare            Cabin Embarked
# PassengerId
# 894              0    240276    9.6875              NaN        Q
# 905              0     24065   26.0000              NaN        S
# 912              0  PC 17603   59.4000              NaN        C
# 973              0  PC 17483  221.7792          C55 C57        S
# 1023             0    113780   28.5000              C51        C
# 1034             3  PC 17608  262.3750  B57 B59 B63 B66        C
# 1044             0      3701       NaN              NaN        S
# 1069             0     11778   55.4417             C116        C
# 1085             0    235509   12.3500              NaN        Q
# 1109             1     36928  164.8667              NaN        S
# 1128             0    110813   75.2500              D37        C
# 1185             1     33638   81.8583              A34        S
# 1200             1     12749   93.5000              B69        S
# 1208             0  PC 17569  146.5208              B78        C
# 1270             0       680   50.0000              C39        S
# 1279             0    244346   13.0000              NaN        S

# %%
mylist[1]

# %%
mydict = { 'almoco': 'quibe',
           'janta': 'quibe2'
            }

# %%
mydict['almoco']

# %%
type(df['Sex'])
