# %%
import pandas as pd
import numpy as np

# %%
! ls ../data
# Out:
# aluguel.csv  gender_submission.csv  ml-100k  test.csv  train.csv

# %%
df = pd.read_csv("../data/test.csv")

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
type(df.shape)
# Out:
# tuple

# %%
df = pd.read_csv("/")

# %%
! ls /home/gabriel/
# Out:
# anaconda3  Downloads	     mozilla.pdf  Public    Templates
# decred	   examples.desktop  Music	  snap	    Videos
# Desktop    Instalation	     Pictures	  Telegram  zshrc.bkp
# Documents  Instalations      programas	  temp

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
df['Sex'].value_counts()
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
minhalista = [1,2,3]
minhalista
# Out:
# [1, 2, 3]

# %%
meudict = {'almoco': 'quibe',
           'janta': 'quibe tambem'}

# %%
meudict['almoco']
# Out:
# 'quibe'

# %%
meudict['cafe da manha'] = 'bacon'

# %%
meudict
# Out:
# {'almoco': 'quibe', 'janta': 'quibe tambem', 'cafe da manha': 'bacon'}

# %%
s1 = pd.Series(minhalista)

# %%
s2 = pd.Series([4,5,6])

# %%
minhalista + minhalista2
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
s1 + s2
# Out:
# 0    5
# 1    7
# 2    9
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
(4*(2 + 3))
# Out:
# 20

# %%
mask = (df['Sex'] == 'male') & (df['Age'] > 60)

# %%
df[mask]
# Out:
#      PassengerId  Pclass                        Name   Sex   Age  SibSp  \
# 2            894       2   Myles, Mr. Thomas Francis  male  62.0      0
# 13           905       2        Howard, Mr. Benjamin  male  63.0      1
# 81           973       1          Straus, Mr. Isidor  male  67.0      1
# 142         1034       1  Ryerson, Mr. Arthur Larned  male  61.0      1
# 152         1044       3          Storey, Mr. Thomas  male  60.5      0
# 193         1085       2           Lingane, Mr. John  male  61.0      0
# 236         1128       1    Warren, Mr. Frank Manley  male  64.0      1
#
#      Parch    Ticket      Fare            Cabin Embarked
# 2        0    240276    9.6875              NaN        Q
# 13       0     24065   26.0000              NaN        S
# 81       0  PC 17483  221.7792          C55 C57        S
# 142      3  PC 17608  262.3750  B57 B59 B63 B66        C
# 152      0      3701       NaN              NaN        S
# ...

# %%
m1 = df['Sex'] == 'male'
m2 = df['Age'] > 40

# %%
display(m1.head(), m2.head())
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# Name: Sex, dtype: bool
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# Name: Age, dtype: bool

# %%
# Out:
# False

# %%
df[~mask]
# Out:
#      PassengerId  Pclass                                               Name  \
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 6            898       3                               Connolly, Miss. Kate
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 15           907       2      del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# 18           910       3                       Ilmakangas, Miss. Ida Livija
# 19           911       3              Assaf Khalil, Mrs. Mariana (Miriam")"
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# ...

# %%
df['SibSp'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 8])

# %%
mask = df['Age'] < 1

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.loc[ mask , 'Age' ] = 0

# %%
df[mask]
# Out:
#      PassengerId  Pclass                                     Name     Sex  \
# 201         1093       3  Danbom, Master. Gilbert Sigvard Emanuel    male
# 250         1142       2                    West, Miss. Barbara J  female
# 281         1173       3           Peacock, Master. Alfred Edward    male
# 307         1199       3                Aks, Master. Philip Frank    male
# 354         1246       3  Dean, Miss. Elizabeth Gladys Millvina""  female
#
#      Age  SibSp  Parch              Ticket    Fare Cabin Embarked
# 201  0.0      0      2              347080  14.400   NaN        S
# 250  0.0      1      2          C.A. 34651  27.750   NaN        S
# 281  0.0      1      1  SOTON/O.Q. 3101315  13.775   NaN        S
# 307  0.0      0      1              392091   9.350   NaN        S
# 354  0.0      1      2           C.A. 2315  20.575   NaN        S

# %%
mask = (df['Sex'] == 'male') & (df['Age'] > 30)

# %%
df['VelhoHomem'] = mask

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  VelhoHomem
# 0  34.5      0      0   330911   7.8292   NaN        Q        True
# 1  47.0      1      0   363272   7.0000   NaN        S       False
# 2  62.0      0      0   240276   9.6875   NaN        Q        True
# 3  27.0      0      0   315154   8.6625   NaN        S       False
# 4  22.0      1      1  3101298  12.2875   NaN        S       False

# %%
df = df.drop(['VelhoHomem'], axis=1)
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df = df.drop(1)
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S
# 5  14.0      0      0     7538   9.2250   NaN        S

# %%
df.shape
# Out:
# (417, 11)

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (417, 11)

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.Fare.sort_values(ascending=False).head()
# Out:
# 343    512.3292
# 69     263.0000
# 53     263.0000
# 59     262.3750
# 375    262.3750
# Name: Fare, dtype: float64

# %%
df.Age.nunique()
# Out:
# 79

# %%
df['grupo'] = (df['Sex'] == 'female') | (df['Age'] < 14)

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
df[(df['Sex'] == 'male') & (df['Age'] > 60)]
# Out:
#      PassengerId  Pclass                        Name   Sex   Age  SibSp  \
# 2            894       2   Myles, Mr. Thomas Francis  male  62.0      0
# 13           905       2        Howard, Mr. Benjamin  male  63.0      1
# 81           973       1          Straus, Mr. Isidor  male  67.0      1
# 142         1034       1  Ryerson, Mr. Arthur Larned  male  61.0      1
# 152         1044       3          Storey, Mr. Thomas  male  60.5      0
# 193         1085       2           Lingane, Mr. John  male  61.0      0
# 236         1128       1    Warren, Mr. Frank Manley  male  64.0      1
#
#      Parch    Ticket      Fare            Cabin Embarked  grupo
# 2        0    240276    9.6875              NaN        Q  False
# 13       0     24065   26.0000              NaN        S  False
# 81       0  PC 17483  221.7792          C55 C57        S  False
# 142      3  PC 17608  262.3750  B57 B59 B63 B66        C  False
# 152      0      3701       NaN              NaN        S  False
# ...

# %%
df[(df['Age'] > 60)]
# Out:
#      PassengerId  Pclass                                               Name  \
# 2            894       2                          Myles, Mr. Thomas Francis
# 13           905       2                               Howard, Mr. Benjamin
# 81           973       1                                 Straus, Mr. Isidor
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 114         1006       1             Straus, Mrs. Isidor (Rosalie Ida Blun)
# 142         1034       1                         Ryerson, Mr. Arthur Larned
# 152         1044       3                                 Storey, Mr. Thomas
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 193         1085       2                                  Lingane, Mr. John
# 236         1128       1                           Warren, Mr. Frank Manley
# 305         1197       1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
#
# ...
