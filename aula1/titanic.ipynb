# %%
########################################
# Author: Robson Zagre Júnior          #
# Copright: <2019> Robson Zagre Júnior #
########################################
#            ,,,         ,,,
#          ;"   ^;     ;'   ",
#          ;    s$$$$$$$s     ;
#          ,  ss$$$$$$$$$$s  ,'
#          ;s$$$$$$$$$$$$$$$
#          $$$$$$$$$$$$$$$$$$
#         $$$$P""Y$$$Y""W$$$$$
#         $$$$  p"$$$"q  $$$$$
#         $$$$  .$$$$$.  $$$$
#          $$DcaU$$$$$$$$$$
#by          "Y$$$"*"$$$Y"    aka
#dcau            "$b.$$"     Panda

# %%
import pandas as pd

# %%
titanic = pd.read_csv("../data/train.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.shape
# Out:
# (891, 12)

# %%
type(titanic.shape)
# Out:
# tuple

# %%
type(titanic.dtypes)
# Out:
# pandas.core.series.Series

# %%
type(titanic.head())
# Out:
# pandas.core.frame.DataFrame

# %%
#======Acessando Dados======

# %%
#==>Media de Idade
titanic["Age"].mean()
# Out:
# 29.69911764705882

# %%
#==>Quantas Pessoas sairam de cada porto
type(titanic.groupby("Embarked").count())
# Out:
# pandas.core.frame.DataFrame

# %%
titanic['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
#==>Pessoa Mais Velha
titanic.sort_values("Age",ascending=False).head(1)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
#==>5 pessoas que pagaram mais caro
titanic.sort_values("Fare", ascending=False).head(5)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 88   female  23.0      3      2     19950  263.0000  C23 C25 C27        S
# 27     male  19.0      3      2     19950  263.0000  C23 C25 C27        S

# %%
#==>Quantos valores diferentes existem em "Age"
titanic["Age"].nunique()
# Out:
# 88

# %%
titanic.loc[ 0:5 , : ]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q

# %%
#======Remodelando a Tabela======

# %%
#==>Renomeando Parch
titanic = titanic.rename(columns={"Parch" : "ParCh"})
#test
titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  ParCh   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
#==>Deletando coluna Ticket
titanic.drop(["Ticket"], axis=1).head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  ParCh     Fare Cabin Embarked
# 0  34.5      0      0   7.8292   NaN        Q
# 1  47.0      1      0   7.0000   NaN        S
# 2  62.0      0      0   9.6875   NaN        Q
# 3  27.0      0      0   8.6625   NaN        S
# 4  22.0      1      1  12.2875   NaN        S

# %%
titanic = titanic.drop(["Ticket"], axis=1)

# %%
#test
titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  ParCh     Fare Cabin Embarked
# 0  34.5      0      0   7.8292   NaN        Q
# 1  47.0      1      0   7.0000   NaN        S
# 2  62.0      0      0   9.6875   NaN        Q
# 3  27.0      0      0   8.6625   NaN        S
# 4  22.0      1      1  12.2875   NaN        S

# %%
titanic.query("Age == 49")
# Out:
#      PassengerId  Survived  Pclass  \
# 52            53         1       1
# 453          454         1       1
# 597          598         0       3
# 599          600         1       1
# 698          699         0       1
# 796          797         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 52       Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1      0
# 453                      Goldenberg, Mr. Samuel L    male  49.0      1      0
# 597                           Johnson, Mr. Alfred    male  49.0      0      0
# 599  Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")    male  49.0      1      0
# 698                      Thayer, Mr. John Borland    male  49.0      1      1
# 796                   Leader, Dr. Alice (Farnham)  female  49.0      0      0
#
#        Ticket      Fare Cabin Embarked
# 52   PC 17572   76.7292   D33        C
# 453     17453   89.1042   C92        C
# 597      LINE    0.0000   NaN        S
# 599  PC 17485   56.9292   A20        C
# 698     17421  110.8833   C68        C
# 796     17465   25.9292   D17        S

# %%
mask = titanic['Sex'] == 'female'

# %%
titanic[mask].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
#==>Correcao de Idade 0 e 1
titanic.loc[titanic["Age"] < 1]
# Out:
#      PassengerId  Pclass                                     Name     Sex  \
# 201         1093       3  Danbom, Master. Gilbert Sigvard Emanuel    male
# 250         1142       2                    West, Miss. Barbara J  female
# 281         1173       3           Peacock, Master. Alfred Edward    male
# 307         1199       3                Aks, Master. Philip Frank    male
# 354         1246       3  Dean, Miss. Elizabeth Gladys Millvina""  female
#
#       Age  SibSp  ParCh    Fare Cabin Embarked
# 201  0.33      0      2  14.400   NaN        S
# 250  0.92      1      2  27.750   NaN        S
# 281  0.75      1      1  13.775   NaN        S
# 307  0.83      0      1   9.350   NaN        S
# 354  0.17      1      2  20.575   NaN        S

# %%
titanic.loc[titanic["Age"] < 1, ["Age"]] = 0
#Verificando alteracoes
titanic.loc[titanic["Age"] < 1]
# Out:
#      PassengerId  Pclass                                     Name     Sex  \
# 201         1093       3  Danbom, Master. Gilbert Sigvard Emanuel    male
# 250         1142       2                    West, Miss. Barbara J  female
# 281         1173       3           Peacock, Master. Alfred Edward    male
# 307         1199       3                Aks, Master. Philip Frank    male
# 354         1246       3  Dean, Miss. Elizabeth Gladys Millvina""  female
#
#      Age  SibSp  ParCh    Fare Cabin Embarked
# 201  0.0      0      2  14.400   NaN        S
# 250  0.0      1      2  27.750   NaN        S
# 281  0.0      1      1  13.775   NaN        S
# 307  0.0      0      1   9.350   NaN        S
# 354  0.0      1      2  20.575   NaN        S

# %%
#Verificando se nao alterou demais valores
titanic.loc[titanic["Age"] < 3]
# Out:
#      PassengerId  Pclass                                     Name     Sex  \
# 89           981       2              Wells, Master. Ralph Lester    male
# 117         1009       3          Sandstrom, Miss. Beatrice Irene  female
# 201         1093       3  Danbom, Master. Gilbert Sigvard Emanuel    male
# 250         1142       2                    West, Miss. Barbara J  female
# 263         1155       3             Klasen, Miss. Gertrud Emilia  female
# 281         1173       3           Peacock, Master. Alfred Edward    male
# 284         1176       3              Rosblom, Miss. Salli Helena  female
# 296         1188       2                    Laroche, Miss. Louise  female
# 307         1199       3                Aks, Master. Philip Frank    male
# 354         1246       3  Dean, Miss. Elizabeth Gladys Millvina""  female
#
#      Age  SibSp  ParCh     Fare Cabin Embarked
# 89   2.0      1      1  23.0000   NaN        S
# 117  1.0      1      1  16.7000    G6        S
# 201  0.0      0      2  14.4000   NaN        S
# 250  0.0      1      2  27.7500   NaN        S
# 263  1.0      1      1  12.1833   NaN        S
# 281  0.0      1      1  13.7750   NaN        S
# 284  2.0      1      1  20.2125   NaN        S
# 296  1.0      1      2  41.5792   NaN        C
# 307  0.0      0      1   9.3500   NaN        S
# 354  0.0      1      2  20.5750   NaN        S

# %%
#==>Mostrar pessoas homens maiores de 60 anos (Nome e Idade apenas)
#Criando mascara (so para treinar hehehe)
old_man_mask = titanic["Age"] > 60
#Quantidade
titanic.loc[old_man_mask].shape[0]
# Out:
# 11

# %%
#Tabela
titanic.loc[old_man_mask, ["Name", "Age"]]
# Out:
#                                                   Name   Age
# 2                            Myles, Mr. Thomas Francis  62.0
# 13                                Howard, Mr. Benjamin  63.0
# 81                                  Straus, Mr. Isidor  67.0
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  76.0
# 114             Straus, Mrs. Isidor (Rosalie Ida Blun)  63.0
# 142                         Ryerson, Mr. Arthur Larned  61.0
# 152                                 Storey, Mr. Thomas  60.5
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  64.0
# 193                                  Lingane, Mr. John  61.0
# 236                           Warren, Mr. Frank Manley  64.0
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  64.0

# %%
titanic.head() #Tudo ok
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  ParCh     Fare Cabin Embarked
# 0  34.5      0      0   7.8292   NaN        Q
# 1  47.0      1      0   7.0000   NaN        S
# 2  62.0      0      0   9.6875   NaN        Q
# 3  27.0      0      0   8.6625   NaN        S
# 4  22.0      1      1  12.2875   NaN        S

# %%
#==>Coluna para Grupo Prioridade
#Criando mascara
priority_mask = (titanic["Sex"] == "female") | (titanic["Age"] < 14)

# %%
#Verificando mascara
titanic.loc[priority_mask].head()
# Out:
#     PassengerId  Pclass                                           Name  \
# 1           893       3               Wilkes, Mrs. James (Ellen Needs)
# 4           896       3   Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 6           898       3                           Connolly, Miss. Kate
# 8           900       3      Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 12          904       1  Snyder, Mrs. John Pillsbury (Nelle Stevenson)
#
#        Sex   Age  SibSp  ParCh     Fare Cabin Embarked
# 1   female  47.0      1      0   7.0000   NaN        S
# 4   female  22.0      1      1  12.2875   NaN        S
# 6   female  30.0      0      0   7.6292   NaN        Q
# 8   female  18.0      0      0   7.2292   NaN        C
# 12  female  23.0      1      0  82.2667   B45        S

# %%
titanic["Grupo de Prioridade"] = priority_mask

# %%
titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  ParCh     Fare Cabin Embarked  Grupo de Prioridade
# 0  34.5      0      0   7.8292   NaN        Q                False
# 1  47.0      1      0   7.0000   NaN        S                 True
# 2  62.0      0      0   9.6875   NaN        Q                False
# 3  27.0      0      0   8.6625   NaN        S                False
# 4  22.0      1      1  12.2875   NaN        S                 True
